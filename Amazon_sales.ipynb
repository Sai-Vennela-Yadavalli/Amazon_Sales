# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/jagadeeshsaivennela/Documents/Data Analysis - mini projects/amazon_sales_data 2025.csv")

df
# Out:
#     Order ID      Date        Product     Category  Price  Quantity  \
# 0    ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 1    ORD0002  20-03-25     Headphones  Electronics    100         4
# 2    ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 3    ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 4    ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ..       ...       ...            ...          ...    ...       ...
# 245  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# 246  ORD0247  30-03-25          Jeans     Clothing     40         1
# 247  ORD0248  05-03-25        T-Shirt     Clothing     20         2
# 248  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# 249  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
#      Total Sales  Customer Name Customer Location Payment Method     Status
# ...

# %%
#just to make sure the columns names are correct
df.columns
# Out:
# Index(['Order ID', 'Date', 'Product', 'Category', 'Price', 'Quantity',
#        'Total Sales', 'Customer Name', 'Customer Location', 'Payment Method',
#        'Status'],
#       dtype='object')

# %%
# checking the data types of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           250 non-null    object
#  1   Date               250 non-null    object
#  2   Product            250 non-null    object
#  3   Category           250 non-null    object
#  4   Price              250 non-null    int64
#  5   Quantity           250 non-null    int64
#  6   Total Sales        250 non-null    int64
#  7   Customer Name      250 non-null    object
#  8   Customer Location  250 non-null    object
#  9   Payment Method     250 non-null    object
#  10  Status             250 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 21.6+ KB

# %%
# To check the missing values
df.isnull().sum()
# Out:
# Order ID             0
# Date                 0
# Product              0
# Category             0
# Price                0
# Quantity             0
# Total Sales          0
# Customer Name        0
# Customer Location    0
# Payment Method       0
# Status               0
# dtype: int64

# %%
# it shows only the numerical columns
df.describe()
# Out:
#              Price    Quantity  Total Sales
# count   250.000000  250.000000   250.000000
# mean    343.580000    2.856000   975.380000
# std     380.635808    1.429489  1252.112254
# min      15.000000    1.000000    15.000000
# 25%      40.000000    2.000000   100.000000
# 50%     150.000000    3.000000   400.000000
# 75%     600.000000    4.000000  1500.000000
# max    1200.000000    5.000000  6000.000000

# %%
# Checking non-numerical columns
df.describe(include='object')
# Out:
#        Order ID      Date     Product     Category Customer Name  \
# count       250       250         250          250           250
# unique      250        60          10            5            10
# top     ORD0001  10-02-25  Smartphone  Electronics    Emma Clark
# freq          1        10          35          118            32
#
#        Customer Location Payment Method     Status
# count                250            250        250
# unique                10              5          3
# top              Houston         PayPal  Completed
# freq                  32             60         88

# %%
df.Product.unique()
# Out:
# array(['Running Shoes', 'Headphones', 'Smartwatch', 'T-Shirt',
#        'Smartphone', 'Book', 'Jeans', 'Laptop', 'Washing Machine',
#        'Refrigerator'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.Date = pd.to_datetime(df["Date"], format="%d-%m-%y")
print(df)
# Out:
#     Order ID       Date        Product     Category  Price  Quantity  \
# 0    ORD0001 2025-03-14  Running Shoes     Footwear     60         3
# 1    ORD0002 2025-03-20     Headphones  Electronics    100         4
# 2    ORD0003 2025-02-15  Running Shoes     Footwear     60         2
# 3    ORD0004 2025-02-19  Running Shoes     Footwear     60         3
# 4    ORD0005 2025-03-10     Smartwatch  Electronics    150         3
# ..       ...        ...            ...          ...    ...       ...
# 245  ORD0246 2025-03-17        T-Shirt     Clothing     20         2
# 246  ORD0247 2025-03-30          Jeans     Clothing     40         1
# 247  ORD0248 2025-03-05        T-Shirt     Clothing     20         2
# 248  ORD0249 2025-03-08     Smartwatch  Electronics    150         3
# 249  ORD0250 2025-02-19     Smartphone  Electronics    500         4
#
#      Total Sales  Customer Name Customer Location Payment Method     Status
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           250 non-null    object
#  1   Date               250 non-null    datetime64[ns]
#  2   Product            250 non-null    object
#  3   Category           250 non-null    object
#  4   Price              250 non-null    int64
#  5   Quantity           250 non-null    int64
#  6   Total Sales        250 non-null    int64
#  7   Customer Name      250 non-null    object
#  8   Customer Location  250 non-null    object
#  9   Payment Method     250 non-null    object
#  10  Status             250 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 21.6+ KB

# %%
# To remove unwanted column
df.drop(columns=["Order ID"], inplace=True)

# %%
df
# Out:
#           Date        Product     Category  Price  Quantity  Total Sales  \
# 0   2025-03-14  Running Shoes     Footwear     60         3          180
# 1   2025-03-20     Headphones  Electronics    100         4          400
# 2   2025-02-15  Running Shoes     Footwear     60         2          120
# 3   2025-02-19  Running Shoes     Footwear     60         3          180
# 4   2025-03-10     Smartwatch  Electronics    150         3          450
# ..         ...            ...          ...    ...       ...          ...
# 245 2025-03-17        T-Shirt     Clothing     20         2           40
# 246 2025-03-30          Jeans     Clothing     40         1           40
# 247 2025-03-05        T-Shirt     Clothing     20         2           40
# 248 2025-03-08     Smartwatch  Electronics    150         3          450
# 249 2025-02-19     Smartphone  Electronics    500         4         2000
#
#      Customer Name Customer Location Payment Method     Status
# ...

# %%
#Ensure Price and Total Sales are floats:
df['Price'] = df['Price'].astype(float)
df['Total Sales'] = df['Total Sales'].astype(float)
df['Quantity'] = df['Quantity'].astype(int)

# %%
df.groupby('Date')['Total Sales'].sum().plot(figsize=(12,6))
plt.title('Total Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# Prepared top 10 products
top_products = df.groupby('Product')['Total Sales'].sum().sort_values(ascending=False).head(10).reset_index()

# Setting style
sns.set_style("darkgrid")

# Ploted using Seaborn with dark gradient color and no warning
plt.figure(figsize=(10,6))
sns.barplot(data=top_products, x='Product', y='Total Sales', hue='Product', palette='Set2', legend=False)

# Customising
plt.title('Top 10 Bestselling Products', fontsize=16)
plt.xlabel('Product Name')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df.groupby('Category')['Total Sales'].sum().plot(kind='bar', color='green')
plt.title('Sales by Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %%
df['Payment Method'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8,8))
plt.title('Payment Method Distribution')
plt.ylabel('')
plt.show()

# %%
df['Status'].value_counts().plot(kind='bar', color='purple')
plt.title('Order Status Count')
plt.xlabel('Status')
plt.ylabel('Number of Orders')
plt.show()

# %%
df['Customer Location'].value_counts().head(10).plot(kind='bar', color='red')
plt.title('Top 10 Customer Locations')
plt.xlabel('Location')
plt.ylabel('Number of Orders')
plt.show()
